# %%
# !pip install catboost mlflow
# Out:
# Collecting catboost
#   Downloading catboost-1.2.8-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Collecting mlflow
#   Downloading mlflow-3.8.1-py3-none-any.whl.metadata (31 kB)
# Collecting graphviz (from catboost)
#   Downloading graphviz-0.21-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: matplotlib in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from catboost) (3.10.8)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from catboost) (2.2.6)
# Requirement already satisfied: pandas>=0.24 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from catboost) (2.3.3)
# Requirement already satisfied: scipy in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from catboost) (1.15.3)
# Collecting plotly (from catboost)
#   Downloading plotly-6.5.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: six in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from catboost) (1.17.0)
# Collecting mlflow-skinny==3.8.1 (from mlflow)
#   Downloading mlflow_skinny-3.8.1-py3-none-any.whl.metadata (31 kB)
# Collecting mlflow-tracing==3.8.1 (from mlflow)
#   Downloading mlflow_tracing-3.8.1-py3-none-any.whl.metadata (19 kB)
# Collecting Flask-CORS<7 (from mlflow)
#   Downloading flask_cors-6.0.2-py3-none-any.whl.metadata (5.3 kB)
# Collecting Flask<4 (from mlflow)
#   Downloading flask-3.1.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Downloading alembic-1.17.2-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: cryptography<47,>=43.0.0 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from mlflow) (46.0.3)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<24 (from mlflow)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting huey<3,>=2.5.0 (from mlflow)
#   Downloading huey-2.5.5-py3-none-any.whl.metadata (4.8 kB)
# Collecting pyarrow<23,>=4.0.0 (from mlflow)
#   Downloading pyarrow-22.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: scikit-learn<2 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from mlflow) (1.7.2)
# Collecting sqlalchemy<3,>=1.4.0 (from mlflow)
#   Downloading sqlalchemy-2.0.45-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Collecting cachetools<7,>=5.0.0 (from mlflow-skinny==3.8.1->mlflow)
#   Downloading cachetools-6.2.4-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: click<9,>=7.0 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from mlflow-skinny==3.8.1->mlflow) (8.3.1)
# Collecting cloudpickle<4 (from mlflow-skinny==3.8.1->mlflow)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.8.1->mlflow)
#   Downloading databricks_sdk-0.76.0-py3-none-any.whl.metadata (40 kB)
# Collecting fastapi<1 (from mlflow-skinny==3.8.1->mlflow)
#   Downloading fastapi-0.128.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from mlflow-skinny==3.8.1->mlflow) (3.1.45)
# Collecting importlib_metadata!=4.7.0,<9,>=3.7.0 (from mlflow-skinny==3.8.1->mlflow)
#   Downloading importlib_metadata-8.7.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==3.8.1->mlflow)
#   Downloading opentelemetry_api-1.39.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-proto<3,>=1.9.0 (from mlflow-skinny==3.8.1->mlflow)
#   Downloading opentelemetry_proto-1.39.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==3.8.1->mlflow)
#   Downloading opentelemetry_sdk-1.39.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: packaging<26 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from mlflow-skinny==3.8.1->mlflow) (25.0)
# Collecting protobuf<7,>=3.12.0 (from mlflow-skinny==3.8.1->mlflow)
#   Downloading protobuf-6.33.2-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Requirement already satisfied: pydantic<3,>=2.0.0 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from mlflow-skinny==3.8.1->mlflow) (2.12.5)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from mlflow-skinny==3.8.1->mlflow) (1.2.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from mlflow-skinny==3.8.1->mlflow) (6.0.3)
# Requirement already satisfied: requests<3,>=2.17.3 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from mlflow-skinny==3.8.1->mlflow) (2.32.5)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==3.8.1->mlflow)
#   Downloading sqlparse-0.5.5-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from mlflow-skinny==3.8.1->mlflow) (4.15.0)
# Collecting uvicorn<1 (from mlflow-skinny==3.8.1->mlflow)
#   Downloading uvicorn-0.40.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow)
#   Downloading mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: tomli in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow) (2.3.0)
# Requirement already satisfied: cffi>=2.0.0 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from cryptography<47,>=43.0.0->mlflow) (2.0.0)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow)
#   Downloading google_auth-2.45.0-py2.py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from docker<8,>=4.0.0->mlflow) (2.6.2)
# Collecting starlette<0.51.0,>=0.40.0 (from fastapi<1->mlflow-skinny==3.8.1->mlflow)
#   Downloading starlette-0.50.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi<1->mlflow-skinny==3.8.1->mlflow)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting blinker>=1.9.0 (from Flask<4->mlflow)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting itsdangerous>=2.2.0 (from Flask<4->mlflow)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: jinja2>=3.1.2 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from Flask<4->mlflow) (3.0.3)
# Collecting werkzeug>=3.1.0 (from Flask<4->mlflow)
#   Downloading werkzeug-3.1.4-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.8.1->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.8.1->mlflow) (5.0.2)
# Collecting pyasn1-modules>=0.2.1 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow)
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_core-3.2.7-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Collecting zipp>=3.20 (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.8.1->mlflow)
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from matplotlib->catboost) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from matplotlib->catboost) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from matplotlib->catboost) (1.4.9)
# Requirement already satisfied: pillow>=8 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from matplotlib->catboost) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from matplotlib->catboost) (3.2.5)
# Collecting opentelemetry-semantic-conventions==0.60b1 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.8.1->mlflow)
#   Downloading opentelemetry_semantic_conventions-0.60b1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: pytz>=2020.1 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.8.1->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.8.1->mlflow) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.8.1->mlflow) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.8.1->mlflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.8.1->mlflow) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.8.1->mlflow) (2025.11.12)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: joblib>=1.2.0 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from scikit-learn<2->mlflow) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Collecting greenlet>=1 (from sqlalchemy<3,>=1.4.0->mlflow)
#   Downloading greenlet-3.3.0-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: anyio<5,>=3.6.2 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.8.1->mlflow) (4.12.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.8.1->mlflow) (1.3.0)
# Requirement already satisfied: h11>=0.8 in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from uvicorn<1->mlflow-skinny==3.8.1->mlflow) (0.16.0)
# Requirement already satisfied: pycparser in /home/kaan/miniconda3/envs/churn/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow) (2.23)
# Collecting narwhals>=1.15.1 (from plotly->catboost)
#   Downloading narwhals-2.14.0-py3-none-any.whl.metadata (13 kB)
# Downloading catboost-1.2.8-cp310-cp310-manylinux2014_x86_64.whl (99.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 1.0 MB/s  0:01:32m0:00:0100:030m
# Downloading mlflow-3.8.1-py3-none-any.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 1.1 MB/s  0:00:08m0:00:0100:01
# Downloading mlflow_skinny-3.8.1-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 1.6 MB/s  0:00:01 eta 0:00:01
# Downloading mlflow_tracing-3.8.1-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 1.8 MB/s  0:00:00 eta 0:00:01
# Downloading alembic-1.17.2-py3-none-any.whl (248 kB)
# Downloading cachetools-6.2.4-py3-none-any.whl (11 kB)
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading databricks_sdk-0.76.0-py3-none-any.whl (774 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 774.7/774.7 kB 594.3 kB/s  0:00:01eta 0:00:01
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
# Downloading fastapi-0.128.0-py3-none-any.whl (103 kB)
# Downloading flask-3.1.2-py3-none-any.whl (103 kB)
# Downloading flask_cors-6.0.2-py3-none-any.whl (13 kB)
# Downloading google_auth-2.45.0-py2.py3-none-any.whl (233 kB)
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Downloading graphql_core-3.2.7-py3-none-any.whl (207 kB)
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
# Downloading huey-2.5.5-py3-none-any.whl (76 kB)
# Downloading importlib_metadata-8.7.1-py3-none-any.whl (27 kB)
# Downloading opentelemetry_api-1.39.1-py3-none-any.whl (66 kB)
# Downloading opentelemetry_proto-1.39.1-py3-none-any.whl (72 kB)
# Downloading opentelemetry_sdk-1.39.1-py3-none-any.whl (132 kB)
# Downloading opentelemetry_semantic_conventions-0.60b1-py3-none-any.whl (219 kB)
# Downloading protobuf-6.33.2-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
# Downloading pyarrow-22.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (47.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 1.1 MB/s  0:00:45m0:00:0100:020m
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading sqlalchemy-2.0.45-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 752.3 kB/s  0:00:04 eta 0:00:01
# Downloading sqlparse-0.5.5-py3-none-any.whl (46 kB)
# Downloading starlette-0.50.0-py3-none-any.whl (74 kB)
# Downloading uvicorn-0.40.0-py3-none-any.whl (68 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading greenlet-3.3.0-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (586 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 586.9/586.9 kB 1.0 MB/s  0:00:0036m-:--:--
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading werkzeug-3.1.4-py3-none-any.whl (224 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Downloading graphviz-0.21-py3-none-any.whl (47 kB)
# Downloading mako-1.3.10-py3-none-any.whl (78 kB)
# Downloading plotly-6.5.0-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 1.2 MB/s  0:00:08m0:00:0100:010m
# Downloading narwhals-2.14.0-py3-none-any.whl (430 kB)
# Installing collected packages: huey, zipp, werkzeug, uvicorn, sqlparse, pyasn1, pyarrow, protobuf, narwhals, Mako, itsdangerous, gunicorn, greenlet, graphviz, graphql-core, cloudpickle, cachetools, blinker, annotated-doc, sqlalchemy, rsa, pyasn1-modules, plotly, opentelemetry-proto, importlib_metadata, graphql-relay, Flask, docker, starlette, opentelemetry-api, graphene, google-auth, Flask-CORS, catboost, alembic, opentelemetry-semantic-conventions, fastapi, databricks-sdk, opentelemetry-sdk, mlflow-tracing, mlflow-skinny, mlflow
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42/42 [mlflow] [mlflow] [mlflow-skinny]]c-conventions]
# Successfully installed Flask-3.1.2 Flask-CORS-6.0.2 Mako-1.3.10 alembic-1.17.2 annotated-doc-0.0.4 blinker-1.9.0 cachetools-6.2.4 catboost-1.2.8 cloudpickle-3.1.2 databricks-sdk-0.76.0 docker-7.1.0 fastapi-0.128.0 google-auth-2.45.0 graphene-3.4.3 graphql-core-3.2.7 graphql-relay-3.2.0 graphviz-0.21 greenlet-3.3.0 gunicorn-23.0.0 huey-2.5.5 importlib_metadata-8.7.1 itsdangerous-2.2.0 mlflow-3.8.1 mlflow-skinny-3.8.1 mlflow-tracing-3.8.1 narwhals-2.14.0 opentelemetry-api-1.39.1 opentelemetry-proto-1.39.1 opentelemetry-sdk-1.39.1 opentelemetry-semantic-conventions-0.60b1 plotly-6.5.0 protobuf-6.33.2 pyarrow-22.0.0 pyasn1-0.6.1 pyasn1-modules-0.4.2 rsa-4.9.1 sqlalchemy-2.0.45 sqlparse-0.5.5 starlette-0.50.0 uvicorn-0.40.0 werkzeug-3.1.4 zipp-3.23.0

# %%
import os
import json
import numpy as np
import pandas as pd

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, confusion_matrix
)

from catboost import CatBoostClassifier
import mlflow
import mlflow.catboost
import joblib


# ---------------- CONFIG ----------------
TRAIN_CSV = "../data/processed/train.csv"
VAL_CSV = "../data/processed/val.csv"
TEST_CSV = "../data/processed/test.csv"

EXPERIMENT_NAME = "customer-churn-merged-split"
OUT_DIR = "../artifacts"

RANDOM_STATE = 42

TARGET = "Churn"
ID_COL = "CustomerID"

CAT_COLS = ["Gender", "Subscription Type", "Contract Length"]
NUM_COLS = [
    "Age","Tenure","Usage Frequency",
    "Support Calls","Payment Delay",
    "Total Spend","Last Interaction"
]

DROP_FEATURES = []   # optionally add ["Total Spend"] etc.


# ---------------- HELPERS ----------------
def split_xy(df):
    """Separate features and target"""
    y = df[TARGET].values
    X = df.drop(columns=[TARGET, ID_COL], errors="ignore")
    if DROP_FEATURES:
        X = X.drop(columns=[c for c in DROP_FEATURES if c in X.columns])
    return X, y

def evaluate(y_true, proba, threshold=0.5):
    """Standard binary classification metrics"""
    pred = (proba >= threshold).astype(int)
    return {
        "accuracy": accuracy_score(y_true, pred),
        "precision": precision_score(y_true, pred, zero_division=0),
        "recall": recall_score(y_true, pred, zero_division=0),
        "f1": f1_score(y_true, pred, zero_division=0),
        "roc_auc": roc_auc_score(y_true, proba),
        "pred_pos_rate": pred.mean(),
        "confusion_matrix": confusion_matrix(y_true, pred).tolist()
    }


# ---------------- MAIN ----------------
def main():
    os.makedirs(OUT_DIR, exist_ok=True)

    # ---- Load processed datasets ----
    df_train = pd.read_csv(TRAIN_CSV)
    df_val = pd.read_csv(VAL_CSV)
    df_test = pd.read_csv(TEST_CSV)

    # ---- Split features and target ----
    X_train, y_train = split_xy(df_train)
    X_val, y_val = split_xy(df_val)
    X_test, y_test = split_xy(df_test)

    cat_cols = [c for c in CAT_COLS if c in X_train.columns]

    # ---- Model ----
    model = CatBoostClassifier(
        loss_function="Logloss",
        eval_metric="AUC",
        iterations=2000,
        learning_rate=0.05,
        depth=6,
        l2_leaf_reg=5,
        random_seed=RANDOM_STATE,
        early_stopping_rounds=100,
        verbose=200
    )

    # ---- MLflow ----
    mlflow.set_experiment(EXPERIMENT_NAME)
    with mlflow.start_run():
        mlflow.log_params({
            "model": "CatBoostClassifier",
            "iterations": 2000,
            "learning_rate": 0.05,
            "depth": 6,
            "drop_features": ",".join(DROP_FEATURES) if DROP_FEATURES else "NONE"
        })

        # Train with validation
        model.fit(
            X_train, y_train,
            eval_set=(X_val, y_val),
            cat_features=cat_cols,
            use_best_model=True
        )

        # Test evaluation
        test_proba = model.predict_proba(X_test)[:, 1]
        metrics = evaluate(y_test, test_proba)

        print("\nTEST METRICS @0.5")
        for k, v in metrics.items():
            if k != "confusion_matrix":
                print(f"{k}: {v}")
        print("Confusion matrix:")
        print(np.array(metrics["confusion_matrix"]))

        # Log metrics
        for k, v in metrics.items():
            if k != "confusion_matrix":
                mlflow.log_metric(k, v)

        # Save artifacts
        report_path = os.path.join(OUT_DIR, "test_report.json")
        with open(report_path, "w") as f:
            json.dump(metrics, f, indent=2)
        mlflow.log_artifact(report_path)

        model_path = os.path.join(OUT_DIR, "catboost_model.cbm")
        model.save_model(model_path)
        mlflow.log_artifact(model_path)

        meta_path = os.path.join(OUT_DIR, "model_meta.joblib")
        joblib.dump({
            "cat_cols": cat_cols,
            "drop_features": DROP_FEATURES,
            "target": TARGET
        }, meta_path)
        mlflow.log_artifact(meta_path)

        mlflow.catboost.log_model(model, name="model")

    print("\nDONE. Using processed train/val/test splits + MLflow tracking.")

if __name__ == "__main__":
    main()
# Out:
# 0:	test: 0.9316922	best: 0.9316922 (0)	total: 83.9ms	remaining: 2m 47s
# 200:	test: 0.9540092	best: 0.9540092 (200)	total: 10.7s	remaining: 1m 35s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.9541535515
# bestIteration = 272
#
# Shrink model to first 273 iterations.
#
# TEST METRICS @0.5
# accuracy: 0.931721462362186
# precision: 0.8988456175621777
# recall: 0.9882350844043566
# f1: 0.9414231980777231
# roc_auc: 0.9534640983102148
# pred_pos_rate: 0.61041942954415
# Confusion matrix:
# [[38704  6239]
#  [  660 55439]]
#
# DONE. Using processed train/val/test splits + MLflow tracking.
