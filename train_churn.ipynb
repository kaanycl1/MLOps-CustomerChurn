# %%
# !pip install catboost mlflow
# Out:
# Collecting catboost
#   Downloading catboost-1.2.8-cp313-cp313-win_amd64.whl.metadata (1.5 kB)
# Collecting mlflow
#   Downloading mlflow-3.7.0-py3-none-any.whl.metadata (31 kB)
# Collecting graphviz (from catboost)
#   Downloading graphviz-0.21-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: matplotlib in c:\users\mfurk\anaconda3\lib\site-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in c:\users\mfurk\anaconda3\lib\site-packages (from catboost) (2.1.3)
# Requirement already satisfied: pandas>=0.24 in c:\users\mfurk\anaconda3\lib\site-packages (from catboost) (2.2.3)
# Requirement already satisfied: scipy in c:\users\mfurk\anaconda3\lib\site-packages (from catboost) (1.15.3)
# Requirement already satisfied: plotly in c:\users\mfurk\anaconda3\lib\site-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in c:\users\mfurk\anaconda3\lib\site-packages (from catboost) (1.17.0)
# Collecting mlflow-skinny==3.7.0 (from mlflow)
#   Downloading mlflow_skinny-3.7.0-py3-none-any.whl.metadata (31 kB)
# Collecting mlflow-tracing==3.7.0 (from mlflow)
#   Downloading mlflow_tracing-3.7.0-py3-none-any.whl.metadata (19 kB)
# Collecting Flask-CORS<7 (from mlflow)
#   Downloading flask_cors-6.0.2-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: Flask<4 in c:\users\mfurk\anaconda3\lib\site-packages (from mlflow) (3.1.0)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\mfurk\anaconda3\lib\site-packages (from mlflow) (1.16.5)
# Requirement already satisfied: cryptography<47,>=43.0.0 in c:\users\mfurk\anaconda3\lib\site-packages (from mlflow) (44.0.1)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting huey<3,>=2.5.0 (from mlflow)
#   Downloading huey-2.5.5-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pyarrow<23,>=4.0.0 in c:\users\mfurk\anaconda3\lib\site-packages (from mlflow) (19.0.0)
# Requirement already satisfied: scikit-learn<2 in c:\users\mfurk\anaconda3\lib\site-packages (from mlflow) (1.6.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\mfurk\anaconda3\lib\site-packages (from mlflow) (2.0.39)
# Collecting waitress<4 (from mlflow)
#   Downloading waitress-3.0.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: cachetools<7,>=5.0.0 in c:\users\mfurk\anaconda3\lib\site-packages (from mlflow-skinny==3.7.0->mlflow) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\mfurk\anaconda3\lib\site-packages (from mlflow-skinny==3.7.0->mlflow) (8.1.8)
# Requirement already satisfied: cloudpickle<4 in c:\users\mfurk\anaconda3\lib\site-packages (from mlflow-skinny==3.7.0->mlflow) (3.0.0)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.7.0->mlflow)
#   Downloading databricks_sdk-0.74.0-py3-none-any.whl.metadata (40 kB)
# Collecting fastapi<1 (from mlflow-skinny==3.7.0->mlflow)
#   Downloading fastapi-0.124.4-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\mfurk\anaconda3\lib\site-packages (from mlflow-skinny==3.7.0->mlflow) (3.1.43)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in c:\users\mfurk\anaconda3\lib\site-packages (from mlflow-skinny==3.7.0->mlflow) (8.5.0)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==3.7.0->mlflow)
#   Downloading opentelemetry_api-1.39.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-proto<3,>=1.9.0 (from mlflow-skinny==3.7.0->mlflow)
#   Downloading opentelemetry_proto-1.39.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==3.7.0->mlflow)
#   Downloading opentelemetry_sdk-1.39.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: packaging<26 in c:\users\mfurk\anaconda3\lib\site-packages (from mlflow-skinny==3.7.0->mlflow) (24.2)
# Requirement already satisfied: protobuf<7,>=3.12.0 in c:\users\mfurk\anaconda3\lib\site-packages (from mlflow-skinny==3.7.0->mlflow) (5.29.3)
# Requirement already satisfied: pydantic<3,>=2.0.0 in c:\users\mfurk\anaconda3\lib\site-packages (from mlflow-skinny==3.7.0->mlflow) (2.10.3)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in c:\users\mfurk\anaconda3\lib\site-packages (from mlflow-skinny==3.7.0->mlflow) (1.1.0)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\mfurk\anaconda3\lib\site-packages (from mlflow-skinny==3.7.0->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\mfurk\anaconda3\lib\site-packages (from mlflow-skinny==3.7.0->mlflow) (2.32.3)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==3.7.0->mlflow)
#   Downloading sqlparse-0.5.4-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in c:\users\mfurk\anaconda3\lib\site-packages (from mlflow-skinny==3.7.0->mlflow) (4.12.2)
# Collecting uvicorn<1 (from mlflow-skinny==3.7.0->mlflow)
#   Downloading uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: Mako in c:\users\mfurk\anaconda3\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: colorama in c:\users\mfurk\anaconda3\lib\site-packages (from click<9,>=7.0->mlflow-skinny==3.7.0->mlflow) (0.4.6)
# Requirement already satisfied: cffi>=1.12 in c:\users\mfurk\anaconda3\lib\site-packages (from cryptography<47,>=43.0.0->mlflow) (1.17.1)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.7.0->mlflow)
#   Downloading google_auth-2.43.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting protobuf<7,>=3.12.0 (from mlflow-skinny==3.7.0->mlflow)
#   Downloading protobuf-6.33.2-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: pywin32>=304 in c:\users\mfurk\anaconda3\lib\site-packages (from docker<8,>=4.0.0->mlflow) (308)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\mfurk\anaconda3\lib\site-packages (from docker<8,>=4.0.0->mlflow) (2.3.0)
# Collecting starlette<0.51.0,>=0.40.0 (from fastapi<1->mlflow-skinny==3.7.0->mlflow)
#   Downloading starlette-0.50.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi<1->mlflow-skinny==3.7.0->mlflow)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: Werkzeug>=3.1 in c:\users\mfurk\anaconda3\lib\site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\mfurk\anaconda3\lib\site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in c:\users\mfurk\anaconda3\lib\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in c:\users\mfurk\anaconda3\lib\site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\mfurk\anaconda3\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.7.0->mlflow) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\mfurk\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.7.0->mlflow) (4.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\mfurk\anaconda3\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.7.0->mlflow) (0.2.8)
# Collecting rsa<5,>=3.1.4 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.7.0->mlflow)
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_core-3.2.7-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in c:\users\mfurk\anaconda3\lib\site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in c:\users\mfurk\anaconda3\lib\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.7.0->mlflow) (3.21.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mfurk\anaconda3\lib\site-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\mfurk\anaconda3\lib\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mfurk\anaconda3\lib\site-packages (from matplotlib->catboost) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\mfurk\anaconda3\lib\site-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\mfurk\anaconda3\lib\site-packages (from matplotlib->catboost) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mfurk\anaconda3\lib\site-packages (from matplotlib->catboost) (3.2.0)
# Collecting opentelemetry-semantic-conventions==0.60b1 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.7.0->mlflow)
#   Downloading opentelemetry_semantic_conventions-0.60b1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mfurk\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mfurk\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\mfurk\anaconda3\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.7.0->mlflow) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\mfurk\anaconda3\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.7.0->mlflow) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mfurk\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.7.0->mlflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mfurk\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.7.0->mlflow) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mfurk\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.7.0->mlflow) (2025.4.26)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\mfurk\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.7.0->mlflow) (0.4.8)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\mfurk\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\mfurk\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (3.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\mfurk\anaconda3\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.1.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\mfurk\anaconda3\lib\site-packages (from starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.7.0->mlflow) (4.7.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\mfurk\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.7.0->mlflow) (1.3.0)
# Requirement already satisfied: h11>=0.8 in c:\users\mfurk\anaconda3\lib\site-packages (from uvicorn<1->mlflow-skinny==3.7.0->mlflow) (0.16.0)
# Requirement already satisfied: pycparser in c:\users\mfurk\anaconda3\lib\site-packages (from cffi>=1.12->cryptography<47,>=43.0.0->mlflow) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mfurk\anaconda3\lib\site-packages (from Jinja2>=3.1.2->Flask<4->mlflow) (3.0.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\mfurk\anaconda3\lib\site-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.8-cp313-cp313-win_amd64.whl (102.4 MB)
#    ---------------------------------------- 0.0/102.4 MB ? eta -:--:--
#     --------------------------------------- 2.1/102.4 MB 11.9 MB/s eta 0:00:09
#    - -------------------------------------- 4.5/102.4 MB 11.9 MB/s eta 0:00:09
#    -- ------------------------------------- 6.8/102.4 MB 11.8 MB/s eta 0:00:09
#    --- ------------------------------------ 9.4/102.4 MB 11.8 MB/s eta 0:00:08
#    ---- ----------------------------------- 11.8/102.4 MB 11.8 MB/s eta 0:00:08
#    ----- ---------------------------------- 14.2/102.4 MB 11.8 MB/s eta 0:00:08
#    ------ --------------------------------- 16.8/102.4 MB 11.8 MB/s eta 0:00:08
#    ------- -------------------------------- 19.1/102.4 MB 11.8 MB/s eta 0:00:08
#    -------- ------------------------------- 21.5/102.4 MB 11.8 MB/s eta 0:00:07
#    --------- ------------------------------ 24.1/102.4 MB 11.8 MB/s eta 0:00:07
#    ---------- ----------------------------- 26.5/102.4 MB 11.8 MB/s eta 0:00:07
#    ----------- ---------------------------- 29.1/102.4 MB 11.8 MB/s eta 0:00:07
#    ------------ --------------------------- 31.5/102.4 MB 11.8 MB/s eta 0:00:07
#    ------------- -------------------------- 33.8/102.4 MB 11.8 MB/s eta 0:00:06
#    -------------- ------------------------- 36.2/102.4 MB 11.8 MB/s eta 0:00:06
#    --------------- ------------------------ 38.8/102.4 MB 11.8 MB/s eta 0:00:06
#    ---------------- ----------------------- 41.2/102.4 MB 11.8 MB/s eta 0:00:06
#    ---------------- ----------------------- 43.5/102.4 MB 11.8 MB/s eta 0:00:05
#    ----------------- ---------------------- 45.9/102.4 MB 11.8 MB/s eta 0:00:05
#    ------------------ --------------------- 48.5/102.4 MB 11.8 MB/s eta 0:00:05
#    ------------------- -------------------- 50.9/102.4 MB 11.8 MB/s eta 0:00:05
#    -------------------- ------------------- 53.2/102.4 MB 11.8 MB/s eta 0:00:05
#    --------------------- ------------------ 55.8/102.4 MB 11.8 MB/s eta 0:00:04
#    ---------------------- ----------------- 58.2/102.4 MB 11.8 MB/s eta 0:00:04
#    ----------------------- ---------------- 60.8/102.4 MB 11.8 MB/s eta 0:00:04
#    ------------------------ --------------- 63.2/102.4 MB 11.8 MB/s eta 0:00:04
#    ------------------------- -------------- 65.5/102.4 MB 11.8 MB/s eta 0:00:04
#    -------------------------- ------------- 67.9/102.4 MB 11.8 MB/s eta 0:00:03
#    --------------------------- ------------ 70.5/102.4 MB 11.8 MB/s eta 0:00:03
#    ---------------------------- ----------- 72.9/102.4 MB 11.8 MB/s eta 0:00:03
#    ----------------------------- ---------- 75.2/102.4 MB 11.8 MB/s eta 0:00:03
#    ------------------------------ --------- 77.6/102.4 MB 11.8 MB/s eta 0:00:03
#    ------------------------------- -------- 80.0/102.4 MB 11.8 MB/s eta 0:00:02
#    -------------------------------- ------- 82.6/102.4 MB 11.8 MB/s eta 0:00:02
#    --------------------------------- ------ 84.9/102.4 MB 11.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 87.3/102.4 MB 11.8 MB/s eta 0:00:02
#    ----------------------------------- ---- 89.7/102.4 MB 11.8 MB/s eta 0:00:02
#    ----------------------------------- ---- 92.0/102.4 MB 11.8 MB/s eta 0:00:01
#    ------------------------------------ --- 94.6/102.4 MB 11.8 MB/s eta 0:00:01
#    ------------------------------------- -- 97.0/102.4 MB 11.8 MB/s eta 0:00:01
#    -------------------------------------- - 99.4/102.4 MB 11.8 MB/s eta 0:00:01
#    --------------------------------------  101.7/102.4 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 102.4/102.4 MB 11.6 MB/s  0:00:08
# Downloading mlflow-3.7.0-py3-none-any.whl (8.9 MB)
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    ---------- ----------------------------- 2.4/8.9 MB 11.8 MB/s eta 0:00:01
#    --------------------- ------------------ 4.7/8.9 MB 11.8 MB/s eta 0:00:01
#    ------------------------------- -------- 7.1/8.9 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.9/8.9 MB 11.5 MB/s  0:00:00
# Downloading mlflow_skinny-3.7.0-py3-none-any.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------  2.4/2.4 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 11.4 MB/s  0:00:00
# Downloading mlflow_tracing-3.7.0-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 1.3/1.3 MB 11.2 MB/s  0:00:00
# Downloading databricks_sdk-0.74.0-py3-none-any.whl (764 kB)
#    ---------------------------------------- 0.0/764.2 kB ? eta -:--:--
#    ---------------------------------------- 764.2/764.2 kB 10.6 MB/s  0:00:00
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
# Downloading fastapi-0.124.4-py3-none-any.whl (113 kB)
# Downloading flask_cors-6.0.2-py3-none-any.whl (13 kB)
# Downloading google_auth-2.43.0-py2.py3-none-any.whl (223 kB)
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Downloading graphql_core-3.2.7-py3-none-any.whl (207 kB)
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading huey-2.5.5-py3-none-any.whl (76 kB)
# Downloading opentelemetry_api-1.39.1-py3-none-any.whl (66 kB)
# Downloading opentelemetry_proto-1.39.1-py3-none-any.whl (72 kB)
# Downloading opentelemetry_sdk-1.39.1-py3-none-any.whl (132 kB)
# Downloading opentelemetry_semantic_conventions-0.60b1-py3-none-any.whl (219 kB)
# Downloading protobuf-6.33.2-cp310-abi3-win_amd64.whl (436 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading sqlparse-0.5.4-py3-none-any.whl (45 kB)
# Downloading starlette-0.50.0-py3-none-any.whl (74 kB)
# Downloading uvicorn-0.38.0-py3-none-any.whl (68 kB)
# Downloading waitress-3.0.2-py3-none-any.whl (56 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading graphviz-0.21-py3-none-any.whl (47 kB)
# Installing collected packages: huey, waitress, sqlparse, rsa, protobuf, graphviz, graphql-core, annotated-doc, uvicorn, starlette, opentelemetry-proto, opentelemetry-api, graphql-relay, google-auth, docker, opentelemetry-semantic-conventions, graphene, Flask-CORS, fastapi, databricks-sdk, catboost, opentelemetry-sdk, mlflow-tracing, mlflow-skinny, mlflow
#
#    ----------------------------------------  0/25 [huey]
#    - --------------------------------------  1/25 [waitress]
#    --- ------------------------------------  2/25 [sqlparse]
#   Attempting uninstall: protobuf
#    --- ------------------------------------  2/25 [sqlparse]
#    ------ ---------------------------------  4/25 [protobuf]
#     Found existing installation: protobuf 5.29.3
#    ------ ---------------------------------  4/25 [protobuf]
#     Uninstalling protobuf-5.29.3:
#    ------ ---------------------------------  4/25 [protobuf]
#       Successfully uninstalled protobuf-5.29.3
#    ------ ---------------------------------  4/25 [protobuf]
#    ------ ---------------------------------  4/25 [protobuf]
#    ------ ---------------------------------  4/25 [protobuf]
#    -------- -------------------------------  5/25 [graphviz]
#    --------- ------------------------------  6/25 [graphql-core]
#    --------- ------------------------------  6/25 [graphql-core]
#    --------- ------------------------------  6/25 [graphql-core]
#    --------- ------------------------------  6/25 [graphql-core]
#    ------------ ---------------------------  8/25 [uvicorn]
#    ------------ ---------------------------  8/25 [uvicorn]
#    -------------- -------------------------  9/25 [starlette]
#    ---------------- ----------------------- 10/25 [opentelemetry-proto]
#    ----------------- ---------------------- 11/25 [opentelemetry-api]
#    -------------------- ------------------- 13/25 [google-auth]
#    -------------------- ------------------- 13/25 [google-auth]
#    -------------------- ------------------- 13/25 [google-auth]
#    ---------------------- ----------------- 14/25 [docker]
#    ---------------------- ----------------- 14/25 [docker]
#    ------------------- ------------- 15/25 [opentelemetry-semantic-conventions]
#    ------------------- ------------- 15/25 [opentelemetry-semantic-conventions]
#    ------------------- ------------- 15/25 [opentelemetry-semantic-conventions]
#    ------------------- ------------- 15/25 [opentelemetry-semantic-conventions]
#    ------------------------- -------------- 16/25 [graphene]
#    ------------------------- -------------- 16/25 [graphene]
#    ------------------------- -------------- 16/25 [graphene]
#    --------------------------- ------------ 17/25 [Flask-CORS]
#    ---------------------------- ----------- 18/25 [fastapi]
#    ---------------------------- ----------- 18/25 [fastapi]
#    ------------------------------ --------- 19/25 [databricks-sdk]
#    ------------------------------ --------- 19/25 [databricks-sdk]
#    ------------------------------ --------- 19/25 [databricks-sdk]
#    ------------------------------ --------- 19/25 [databricks-sdk]
#    ------------------------------ --------- 19/25 [databricks-sdk]
#    ------------------------------ --------- 19/25 [databricks-sdk]
#    ------------------------------ --------- 19/25 [databricks-sdk]
#    -------------------------------- ------- 20/25 [catboost]
#    -------------------------------- ------- 20/25 [catboost]
#    -------------------------------- ------- 20/25 [catboost]
#    -------------------------------- ------- 20/25 [catboost]
#    -------------------------------- ------- 20/25 [catboost]
#    -------------------------------- ------- 20/25 [catboost]
#    -------------------------------- ------- 20/25 [catboost]
#    -------------------------------- ------- 20/25 [catboost]
#    --------------------------------- ------ 21/25 [opentelemetry-sdk]
#    --------------------------------- ------ 21/25 [opentelemetry-sdk]
#    ----------------------------------- ---- 22/25 [mlflow-tracing]
#    ----------------------------------- ---- 22/25 [mlflow-tracing]
#    ----------------------------------- ---- 22/25 [mlflow-tracing]
#    ----------------------------------- ---- 22/25 [mlflow-tracing]
#    ----------------------------------- ---- 22/25 [mlflow-tracing]
#    ----------------------------------- ---- 22/25 [mlflow-tracing]
#    ----------------------------------- ---- 22/25 [mlflow-tracing]
#    ----------------------------------- ---- 22/25 [mlflow-tracing]
#    ----------------------------------- ---- 22/25 [mlflow-tracing]
#    ----------------------------------- ---- 22/25 [mlflow-tracing]
#    ----------------------------------- ---- 22/25 [mlflow-tracing]
#    ----------------------------------- ---- 22/25 [mlflow-tracing]
#    ----------------------------------- ---- 22/25 [mlflow-tracing]
#    ----------------------------------- ---- 22/25 [mlflow-tracing]
#    ----------------------------------- ---- 22/25 [mlflow-tracing]
#    ----------------------------------- ---- 22/25 [mlflow-tracing]
#    ----------------------------------- ---- 22/25 [mlflow-tracing]
#    ----------------------------------- ---- 22/25 [mlflow-tracing]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    ------------------------------------ --- 23/25 [mlflow-skinny]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    -------------------------------------- - 24/25 [mlflow]
#    ---------------------------------------- 25/25 [mlflow]
#
# Successfully installed Flask-CORS-6.0.2 annotated-doc-0.0.4 catboost-1.2.8 databricks-sdk-0.74.0 docker-7.1.0 fastapi-0.124.4 google-auth-2.43.0 graphene-3.4.3 graphql-core-3.2.7 graphql-relay-3.2.0 graphviz-0.21 huey-2.5.5 mlflow-3.7.0 mlflow-skinny-3.7.0 mlflow-tracing-3.7.0 opentelemetry-api-1.39.1 opentelemetry-proto-1.39.1 opentelemetry-sdk-1.39.1 opentelemetry-semantic-conventions-0.60b1 protobuf-6.33.2 rsa-4.9.1 sqlparse-0.5.4 starlette-0.50.0 uvicorn-0.38.0 waitress-3.0.2
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import json
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, confusion_matrix
)

from catboost import CatBoostClassifier
import mlflow
import mlflow.catboost
import joblib


# ---------------- CONFIG ----------------
TRAIN_CSV = "customer_churn_dataset-training-master.csv"
TEST_CSV  = "customer_churn_dataset-testing-master.csv"

EXPERIMENT_NAME = "customer-churn-merged-split"
OUT_DIR = "artifacts"

RANDOM_STATE = 42
TEST_SIZE = 0.20
VAL_SIZE  = 0.20

TARGET = "Churn"
ID_COL = "CustomerID"

CAT_COLS = ["Gender", "Subscription Type", "Contract Length"]
NUM_COLS = [
    "Age","Tenure","Usage Frequency",
    "Support Calls","Payment Delay",
    "Total Spend","Last Interaction"
]

DROP_FEATURES = []   # optionally add ["Total Spend"] etc.


# ---------------- HELPERS ----------------
def clean_target(df):
    """Normalize churn labels to {0,1}"""
    df = df.copy()
    df[TARGET] = df[TARGET].replace({
        "Yes": 1, "No": 0,
        "yes": 1, "no": 0,
        True: 1, False: 0
    })
    df[TARGET] = pd.to_numeric(df[TARGET], errors="coerce")
    df = df.dropna(subset=[TARGET])
    df[TARGET] = df[TARGET].astype(int)
    return df[df[TARGET].isin([0, 1])]

def clean_features(df):
    """Basic dtype cleanup"""
    df = df.copy()
    for c in CAT_COLS:
        if c in df.columns:
            df[c] = df[c].astype("string")
    for c in NUM_COLS:
        if c in df.columns:
            df[c] = pd.to_numeric(df[c], errors="coerce")
    return df

def split_xy(df):
    """Separate features and target"""
    y = df[TARGET].values
    X = df.drop(columns=[TARGET, ID_COL], errors="ignore")
    if DROP_FEATURES:
        X = X.drop(columns=[c for c in DROP_FEATURES if c in X.columns])
    return X, y

def evaluate(y_true, proba, threshold=0.5):
    """Standard binary classification metrics"""
    pred = (proba >= threshold).astype(int)
    return {
        "accuracy": accuracy_score(y_true, pred),
        "precision": precision_score(y_true, pred, zero_division=0),
        "recall": recall_score(y_true, pred, zero_division=0),
        "f1": f1_score(y_true, pred, zero_division=0),
        "roc_auc": roc_auc_score(y_true, proba),
        "pred_pos_rate": pred.mean(),
        "confusion_matrix": confusion_matrix(y_true, pred).tolist()
    }


# ---------------- MAIN ----------------
def main():
    os.makedirs(OUT_DIR, exist_ok=True)

    # ---- Load & merge datasets ----
    df_train = pd.read_csv(TRAIN_CSV)
    df_test  = pd.read_csv(TEST_CSV)
    df = pd.concat([df_train, df_test], ignore_index=True)

    df = clean_target(df)
    df = clean_features(df)

    # ---- Train / Val / Test split ----
    X, y = split_xy(df)

    X_tmp, X_test, y_tmp, y_test = train_test_split(
        X, y,
        test_size=TEST_SIZE,
        random_state=RANDOM_STATE,
        stratify=y
    )

    X_train, X_val, y_train, y_val = train_test_split(
        X_tmp, y_tmp,
        test_size=VAL_SIZE,
        random_state=RANDOM_STATE,
        stratify=y_tmp
    )

    cat_cols = [c for c in CAT_COLS if c in X_train.columns]

    # ---- Model ----
    model = CatBoostClassifier(
        loss_function="Logloss",
        eval_metric="AUC",
        iterations=2000,
        learning_rate=0.05,
        depth=6,
        l2_leaf_reg=5,
        random_seed=RANDOM_STATE,
        early_stopping_rounds=100,
        verbose=200
    )

    # ---- MLflow ----
    mlflow.set_experiment(EXPERIMENT_NAME)
    with mlflow.start_run():
        mlflow.log_params({
            "model": "CatBoostClassifier",
            "iterations": 2000,
            "learning_rate": 0.05,
            "depth": 6,
            "drop_features": ",".join(DROP_FEATURES) if DROP_FEATURES else "NONE"
        })

        # Train with validation
        model.fit(
            X_train, y_train,
            eval_set=(X_val, y_val),
            cat_features=cat_cols,
            use_best_model=True
        )

        # Test evaluation
        test_proba = model.predict_proba(X_test)[:, 1]
        metrics = evaluate(y_test, test_proba)

        print("\nTEST METRICS @0.5")
        for k, v in metrics.items():
            if k != "confusion_matrix":
                print(f"{k}: {v}")
        print("Confusion matrix:")
        print(np.array(metrics["confusion_matrix"]))

        # Log metrics
        for k, v in metrics.items():
            if k != "confusion_matrix":
                mlflow.log_metric(k, v)

        # Save artifacts
        report_path = os.path.join(OUT_DIR, "test_report.json")
        with open(report_path, "w") as f:
            json.dump(metrics, f, indent=2)
        mlflow.log_artifact(report_path)

        model_path = os.path.join(OUT_DIR, "catboost_model.cbm")
        model.save_model(model_path)
        mlflow.log_artifact(model_path)

        meta_path = os.path.join(OUT_DIR, "model_meta.joblib")
        joblib.dump({
            "cat_cols": cat_cols,
            "drop_features": DROP_FEATURES,
            "target": TARGET
        }, meta_path)
        mlflow.log_artifact(meta_path)

        mlflow.catboost.log_model(model, name="model")

    print("\nDONE. Clean IID split + sane metrics + MLflow tracking.")

if __name__ == "__main__":
    main()
# Out:
# 0:	test: 0.9316922	best: 0.9316922 (0)	total: 183ms	remaining: 6m 5s
# 200:	test: 0.9537471	best: 0.9537717 (179)	total: 26.8s	remaining: 3m 59s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.9539116604
# bestIteration = 267
#
# Shrink model to first 268 iterations.
#
# TEST METRICS @0.5
# accuracy: 0.9312167217592684
# precision: 0.8986713388815886
# recall: 0.9874507566979803
# f1: 0.9409716324103958
# roc_auc: 0.953458482064828
# pred_pos_rate: 0.6100532451851706
# Confusion matrix:
# [[38697  6246]
#  [  704 55395]]
#
# DONE. Clean IID split + sane metrics + MLflow tracking.
